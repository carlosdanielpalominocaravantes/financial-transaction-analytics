# %%
# !pip install psycopg2-binary SQLAlchemy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 27.6 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
from sqlalchemy import create_engine

print("🔌 Conectando pipeline a la base de datos PostgreSQL en la nube...")

# 1. CARGAR DATOS LIMPIOS DEL DÍA 1
# Cargamos el CSV limpio que generamos en la sesión anterior
df_clean = pd.read_csv('clean_financial_transactions.csv')

# 2. CONFIGURAR LA CONEXIÓN DE BASE DE DATOS
# REEMPLAZA ESTA CADENA con el enlace de conexión largo que te dio Neon.tech
# Nota: Asegúrate de cambiar 'postgres://' por 'postgresql://' si tu enlace empieza así.
DATABASE_URL = "postgresql://neondb_owner:npg_1qXyeRzU2tfw@ep-wild-cake-axhmykvc-pooler.c-4.us-east-2.aws.neon.tech/neondb?sslmode=require&channel_binding=require"

# Crear el motor de conexión
engine = create_engine(DATABASE_URL)

# 3. INYECTAR DATOS EN POSTGRESQL (Cultura Zero-Manual)
# Este comando crea la tabla automáticamente y sube los miles de registros en segundos
df_clean.to_sql('fact_transactions', con=engine, if_exists='replace', index=False)

print("✅ ¡Inyección masiva completada exitosamente! Tabla 'fact_transactions' creada en PostgreSQL.")
# Out:
# 🔌 Conectando pipeline a la base de datos PostgreSQL en la nube...
# ✅ ¡Inyección masiva completada exitosamente! Tabla 'fact_transactions' creada en PostgreSQL.
